# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
weights = np.load("pretrained_attention_weights.npy")

# %%
weights.shape
# Out:
# (10, 2, 301, 4, 8, 30)

# %%
np.sum(weights[5,0,0,0,0,:])
# Out:
# 1.0

# %%
np.sum(weights)
# Out:
# 192640.06

# %%
weights[1,0,0,:,0,10]
# Out:
# array([0.05401726, 0.02404355, 0.03567235, 0.07452548], dtype=float32)

# %%
plt.plot(weights[0,0,0,0,0,:])

# %%
plt.plot(weights[0,0,0,3,0,:])

# %%
plt.scatter(np.arange(0,30),np.sum(weights[5,:,:,:,:,:], axis=(0,1,2,3)))
