# %%
# %run ./src/run.py  --model_name "graphsum" \
               --use_cuda true \
               --is_distributed false \
               --use_multi_gpu_test true \
               --use_fast_executor true \
               --use_fp16 false \
               --use_dynamic_loss_scaling false \
               --init_loss_scaling -128 \
               --weight_sharing true \
               --do_train true \
               --do_val false \
               --do_test true \
               --do_dec true \
               --verbose true \
               --batch_size 4096 \
               --in_tokens true \
               --stream_job "" \
               --init_pretraining_params "" \
               --train_set "E:/graphsum/data/MultiNews_data_tfidf_30_paddle/train" \
               --dev_set "E:/graphsum/data/MultiNews_data_tfidf_30_paddle/valid" \
               --test_set "E:/graphsum/data/MultiNews_data_tfidf_30_paddle/test" \
               --vocab_path "E:/graphsum/data/spm9998_3.model" \
               --config_path ./model_config/graphsum_config.json \
               --checkpoints ./models/graphsum_multinews \
               --decode_path ./results/graphsum_multinews \
               --lr_scheduler "noam_decay" \
               --save_steps 10000 \
               --weight_decay 0.01 \
               --warmup_steps 8000 \
               --validation_steps 20000 \
               --epoch 100 \
               --max_para_num 30 \
               --max_para_len 60 \
               --max_tgt_len 300 \
               --max_out_len 300 \
               --min_out_len 200 \
               --graph_type "similarity" \
               --len_penalty 0.6 \
               --block_trigram True \
               --report_rouge True \
               --learning_rate 2.0 \
               --skip_steps 100 \
               --grad_norm 2.0 \
               --pos_win 2.0 \
               --label_smooth_eps 0.1 \
               --num_iteration_per_drop_scope 10 \
               --log_file "log/graphsum_multinews.log" \
               --random_seed 1
# Out:
# [2020-09-28 19:52:40,373 INFO] {'BOS': 4, 'EOS': 5, 'PAD': 6, 'EOT': 3, 'EOP': 7, 'EOQ': 8, 'UNK': 0}
# -----------  Configuration Arguments -----------
# batch_size: 4096
# beam_size: 5
# beta1: 0.9
# beta2: 0.998
# block_trigram: True
# checkpoints: ./models/graphsum_multinews
# config_path: ./model_config/graphsum_config.json
# decode_path: ./results/graphsum_multinews
# decr_every_n_nan_or_inf: 2
# decr_ratio: 0.8
# dev_set: E:/graphsum/data/MultiNews_data_tfidf_30_paddle/valid
# do_dec: True
# do_lower_case: True
# do_test: True
# do_train: True
# do_val: False
# encoder_json_file: roberta_config/encoder.json
# epoch: 100
# eps: 1e-09
# ernie_config_path: ernie_config/ernie_config.json
# ernie_vocab_file: ernie_config/vocab.txt
# evaluate_blue: False
# grad_norm: 2.0
# graph_type: similarity
# in_tokens: True
# incr_every_n_steps: 100
# incr_ratio: 2.0
# init_checkpoint: None
# init_loss_scaling: -128.0
# init_pretraining_params:
# is_distributed: False
# label_smooth_eps: 0.1
# learning_rate: 2.0
# len_penalty: 0.6
# log_file: log/graphsum_multinews.log
# lr_scheduler: noam_decay
# max_out_len: 300
# max_para_len: 60
# max_para_num: 30
# max_seq_len: 512
# max_tgt_len: 300
# metrics: True
# min_out_len: 200
# model_name: graphsum
# num_iteration_per_drop_scope: 10
# pos_win: 2.0
# random_seed: 1
# report_rouge: True
# roberta_config_path: roberta_config/roberta_config.json
# roberta_vocab_file: roberta_config/vocab.txt
# save_steps: 10000
# skip_steps: 100
# stream_job:
# test_set: E:/graphsum/data/MultiNews_data_tfidf_30_paddle/test
# train_set: E:/graphsum/data/MultiNews_data_tfidf_30_paddle/train
# use_cuda: True
# use_dynamic_loss_scaling: False
# use_fast_executor: True
# use_fp16: False
# use_interval: False
# use_multi_gpu_test: True
# validation_steps: 20000
# verbose: True
# vocab_bpe_file: roberta_config/vocab.bpe
# vocab_path: E:/graphsum/data/spm9998_3.model
# warmup_proportion: 0.1
# warmup_steps: 8000
# weight_decay: 0.01
# weight_sharing: True
# ------------------------------------------------
# attention_probs_dropout_prob: 0.1
# dec_graph_layers: 8
# dec_word_pos_embedding_name: dec_word_pos_embedding
# enc_graph_layers: 2
# enc_sen_pos_embedding_name: enc_sen_pos_embedding
# enc_word_layers: 6
# enc_word_pos_embedding_name: enc_word_pos_embedding
# hidden_act: relu
# hidden_dropout_prob: 0.1
# hidden_size: 256
# initializer_range: 0.02
# max_position_embeddings: 512
# num_attention_heads: 8
# postprocess_command: da
# preprocess_command: n
# word_embedding_name: word_embedding
# ------------------------------------------------
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\Desktop\Git Repos\text_summarization\Research\NLP\ACL2020-GraphSum\src\run.py in <module>
#      33
#      34     if args.model_name == 'graphsum':
# ---> 35         run_graphsum(args)
#      36     else:
#      37         raise ValueError("Model %s is not supported currently!" % args.model_name)
#
# ~\Desktop\Git Repos\text_summarization\Research\NLP\ACL2020-GraphSum\src\networks\graphsum\run_graphsum.py in main(args)
#     111             phase="train")
#     112
# --> 113         num_train_examples = reader.get_num_examples(args.train_set)
#     114
#     115         if args.in_tokens:
#
# ~\Desktop\Git Repos\text_summarization\Research\NLP\ACL2020-GraphSum\src\networks\graphsum\graphsum_reader.py in get_num_examples(self, data_path)
#     125         num_examples = 0
#     126         dataset_loader = self.lazy_load_dataset(data_path)
# --> 127         for dataset in dataset_loader:
#     128             num_examples += len(dataset)
#     129         self.num_examples = num_examples
#
# ~\Desktop\Git Repos\text_summarization\Research\NLP\ACL2020-GraphSum\src\networks\graphsum\graphsum_reader.py in lazy_load_dataset(self, data_path, shuffle)
#     111
#     112             for pt in pts:
# --> 113                 yield _dataset_loader(pt)
#     114
#     115         else:
#
# ~\Desktop\Git Repos\text_summarization\Research\NLP\ACL2020-GraphSum\src\networks\graphsum\graphsum_reader.py in _dataset_loader(pt_file)
#      99
#     100         def _dataset_loader(pt_file):
# --> 101             dataset = json.load(open(pt_file, encoding="utf-8"))
#     102             logger.info('Loading dataset from %s, number of examples: %d' %
#     103                         (pt_file, len(dataset)))
#
# c:\users\arnem\appdata\local\programs\python\python37\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# c:\users\arnem\appdata\local\programs\python\python37\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 2738471: character maps to <undefined>
