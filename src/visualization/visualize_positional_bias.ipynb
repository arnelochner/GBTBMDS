# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import pickle
import os
import sys
from visualize_attention_weights import *
from rouge_scores_sim_visualization import *
import json
# %matplotlib inline

# %% [markdown]
# # Based on Attention Weights

# %%
transformed_attention_weights_path = "../../transformed_attention_weights/multinews"

# %%
sentence_level_aggregation_dict = pickle.load(open(os.path.join(transformed_attention_weights_path, "sentence_level_aggregation_dict"), "rb"))

# %%
result_dict = pickle.load(open(os.path.join(transformed_attention_weights_path, "result_dict"), "rb"))

# %%
histo_simp_per_dec_layer(result_dict,sentence_level_aggregation_dict["Mean"],True)

# %%
for i in range(8):
    histo_simp_per_dec_layer(result_dict,sentence_level_aggregation_dict["Mean"],True, decoding_layer_list=[i], save=True, size=(10,8))

# %%
histo_simp_per_dec_layer(result_dict,sentence_level_aggregation_dict["Mean"],True, decoding_layer_list=[2], save=True, size=(10,8))

# %%
histo_simp_per_dec_layer(result_dict,sentence_level_aggregation_dict["Mean"],True, decoding_layer_list=[5], save=True, size=(10,8))

# %% [markdown]
# # Based on Rouge Scores

# %%
rouge_information_path = "../../rouge_information/"

# %%
rouge_scores = np.load(os.path.join(rouge_information_path, "rouge_full.npy"))
rouge_meta = json.load(open(os.path.join(rouge_information_path, "rouge_meta.json"), "rb"))

# %% [markdown]
# ## Rouge-1

# %%
histo = plot_rouge(rouge_scores, result_dict, rouge_meta, score=0, cmap="cividis")

# %% [markdown]
# ## Rouge-2

# %%
histo = plot_rouge(rouge_scores, result_dict, rouge_meta, score=1, cmap="cividis")

# %% [markdown]
# ## Rouge-L

# %%
histo = plot_rouge(rouge_scores, result_dict, rouge_meta, score=2, cmap="cividis")

# %% [markdown]
# ## Old plots based on 500

# %%
histo_simp_per_dec_layer(result_dict,r["Median"],True)

# %%
histo_simp_per_dec_layer(result_dict,r["Mean"],True, decoding_layer_list=[0,7], save=True, size=(10,8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a6662a8c9ec7> in <module>()
# ----> 1 histo_simp_per_dec_layer(result_dict,r["Mean"],True, decoding_layer_list=[0,7], save=True, size=(10,8))
#
# NameError: name 'r' is not defined
